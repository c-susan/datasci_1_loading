# %% [markdown]
# <a href="https://colab.research.google.com/github/c-susan/datasci_1_loading/blob/main/hha507_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading Package(s)

# %%
import pandas as pd
import seaborn as sns
import plotly as plt

# %%
# !pip freeze > packages.txt

# %% [markdown]
# # Pandas Data Loading

# %% [markdown]
# ### CSV File Datasets:

# %% [markdown]
# **CSV 1: This dataset contains information on Medicare providers specializing in Home Infusion Therapy. Columns in the dataset include the following: Enrollment ID, Legal Business Name, Street Address Line 1, Street Address Line 2, City, State, Zip Code, Practice Location Phone Number, Specialty Name, Geographic Location Type Description, Geographic Location City Name, Geographic Location State Code, Geographic Location Zip Code, and State County Name. The column 'Enrollment ID' indicates the providers' Medicaid enrollment ID, and 'Legal Business Name' indicates the providers' clinic's name. The 'Specialty Name' column indicates the specializations of the providers, which is Home Infusion Therapy. Phone numbers of each provider are listed in the 'Practice Location Phone Number' column. The remaining columns indicate the providers' addresses, including street address, zip code, city, state, county, and geographic location description.**
#
# https://data.cms.gov/provider-characteristics/medicare-provider-supplier-enrollment/home-infusion-therapy-providers

# %%
csv1 = pd.read_csv('https://raw.githubusercontent.com/c-susan/datasci_1_loading/main/data/Home%20Infusion%20Therapy%2008.31.2023.csv')
csv1
# Out:
#         Enrollment ID                   Legal Business Name  \
# 0     O20201116001628               CRESCENT HEALTHCARE INC
# 1     O20220203001062                  MKARE MANAGEMENT INC
# 2     O20230209002788  PRESTIGE FAMILY HOME HEALTH CARE LLC
# 3     O20221102001119                 AMBER ENTERPRISES INC
# 4     O20221102001119                 AMBER ENTERPRISES INC
# ...               ...                                   ...
# 2741  O20221121003136        COMMUNITY CARE PROVIDERS, INC.
# 2742  O20201223001304       HORIZON HOME CARE & HOSPICE INC
# 2743  O20201223001304       HORIZON HOME CARE & HOSPICE INC
# 2744  O20201223001304       HORIZON HOME CARE & HOSPICE INC
# 2745  O20201214001092                      SOLEO HEALTH INC
#
#            Street Address Line 1 Street Address Line 2               City  \
# 0                5431 SW 35TH DR               STE 200        GAINESVILLE
# 1                 147 AUBURN RDG                    --      SPRING BRANCH
# ...

# %%
csv1_top10 = csv1.head(10)
print('First 10 rows: ')
csv1_top10
# Out:
# First 10 rows:
#      Enrollment ID                   Legal Business Name  \
# 0  O20201116001628               CRESCENT HEALTHCARE INC
# 1  O20220203001062                  MKARE MANAGEMENT INC
# 2  O20230209002788  PRESTIGE FAMILY HOME HEALTH CARE LLC
# 3  O20221102001119                 AMBER ENTERPRISES INC
# 4  O20221102001119                 AMBER ENTERPRISES INC
# 5  O20210826002187                INFUSION SOLUTIONS INC
# 6  O20210826002187                INFUSION SOLUTIONS INC
# 7  O20221117001910                 AMBER ENTERPRISES INC
# 8  O20221117001910                 AMBER ENTERPRISES INC
# 9  O20221117001910                 AMBER ENTERPRISES INC
#
#         Street Address Line 1 Street Address Line 2            City State  \
# 0             5431 SW 35TH DR               STE 200     GAINESVILLE    FL
# 1              147 AUBURN RDG                    --   SPRING BRANCH    TX
# 2       1180 N TOWN CENTER DR               STE 100       LAS VEGAS    NV
# ...

# %% [markdown]
# **CSV 2: This dataset contains information on Medicare providers asociated with the Opioid Treatment Program. Columns of the dataset includes providers' national provider identifier (NPI), business name, address, city, state, zip code, effective enrollment date, and phone number.**
#
# https://data.cms.gov/provider-characteristics/medicare-provider-supplier-enrollment/opioid-treatment-program-providers

# %%
csv2 = pd.read_csv('https://raw.githubusercontent.com/c-susan/datasci_1_loading/main/data/OPIOID_TREATMENT_PROGRAM_PROVIDERS_08282023.csv')
csv2
# Out:
#                         NPI                        PROVIDER NAME  \
# 0     1003081399 1013055110  BAART BEHAVIORAL HEALTH SERVICES IN
# 1                1003150004                 AMS OF WISCONSIN LLC
# 2                1003362484                         BHG XLII LLC
# 3                1003368945                         RTS EDGEWOOD
# 4                1003571647        METRO TREATMENT OF FLORIDA LP
# ...                     ...                                  ...
# 1448             1992861553          AEGIS TREATMENT CENTERS LLC
# 1449             1992861694  WESTSIDE METHADONE TREATMENT PROGRA
# 1450             1992941702          CARNEGIE HILL INSTITUTE INC
# 1451             1992966584                      VCPHCS VII, LLC
# 1452             1790700904                ATS AT JHBMC MFL BLDG
#
#                  ADDRESS LINE 1                  ADDRESS LINE 2  \
# 0               617 COMSTOCK RD                           STE 5
# ...

# %%
csv2_top10 = csv2.head(10)
print('First 10 rows: ')
csv2_top10
# Out:
# First 10 rows:
#                      NPI                        PROVIDER NAME  \
# 0  1003081399 1013055110  BAART BEHAVIORAL HEALTH SERVICES IN
# 1             1003150004                 AMS OF WISCONSIN LLC
# 2             1003362484                         BHG XLII LLC
# 3             1003368945                         RTS EDGEWOOD
# 4             1003571647        METRO TREATMENT OF FLORIDA LP
# 5  1003581174 1326713314            PREMIER CARE OF OHIO, LLC
# 6             1003583733  AFFINITY HEALTHCARE GROUP CHERRY HI
# 7             1003947193  WEST TEXAS COUNSELING & REHABILITAT
# 8             1003953548             ALLIANCE RECOVERY CENTER
# 9             1003953548             ALLIANCE RECOVERY CENTER
#
#               ADDRESS LINE 1                  ADDRESS LINE 2            CITY  \
# 0            617 COMSTOCK RD                           STE 5          BERLIN
# 1      9532 E 16 FRONTAGE RD                         STE 100        ONALASKA
# ...

# %% [markdown]
# **CSV 3: This dataset provides information on suppliers enrolled in the Medicare Diabetes Prevention Program (MDPP) from which eligible Medicare beneficiaries can receive services. The program name, Medicare Diabetes Prevention Program (MDPP) Expanded Model, is a column on the dataset along with each supplier organization name. Address is broken down into several columns, including location name, location 1, street address line 1, street address line 2, city, state, and zip code. The phone number and suppliers' national provider identifier (NPI) are listed in their respective columns. The 'Category' column indicates the type of setting/location of the organization. 'Unique ID' indicates a identification number unique to each row.**
#
# https://data.cms.gov/cms-innovation-center-programs/alternative-payments-medicare-diabetes-prevention-program/medicare-diabetes-prevention-program

# %%
csv3 = pd.read_csv('https://raw.githubusercontent.com/c-susan/datasci_1_loading/main/data/MDPP-Supplier-Mapping_06-27-23.csv')
csv3
# Out:
#                                     Name of Initiative  \
# 0    Medicare Diabetes Prevention Program (MDPP) Ex...
# 1    Medicare Diabetes Prevention Program (MDPP) Ex...
# 2    Medicare Diabetes Prevention Program (MDPP) Ex...
# 3    Medicare Diabetes Prevention Program (MDPP) Ex...
# 4    Medicare Diabetes Prevention Program (MDPP) Ex...
# ..                                                 ...
# 949  Medicare Diabetes Prevention Program (MDPP) Ex...
# 950  Medicare Diabetes Prevention Program (MDPP) Ex...
# 951  Medicare Diabetes Prevention Program (MDPP) Ex...
# 952  Medicare Diabetes Prevention Program (MDPP) Ex...
# 953  Medicare Diabetes Prevention Program (MDPP) Ex...
#
#                                     Organization Name  \
# 0                   Comunidad Saludable De La Montana
# 1                   Comunidad Saludable De La Montana
# 2                   Comunidad Saludable De La Montana
# 3    Hockomock Young Men'S Christian Association Inc.
# ...

# %%
csv3_top10 = csv3.head(10)
print('First 10 rows: ')
csv3_top10
# Out:
# First 10 rows:
#                                   Name of Initiative  \
# 0  Medicare Diabetes Prevention Program (MDPP) Ex...
# 1  Medicare Diabetes Prevention Program (MDPP) Ex...
# 2  Medicare Diabetes Prevention Program (MDPP) Ex...
# 3  Medicare Diabetes Prevention Program (MDPP) Ex...
# 4  Medicare Diabetes Prevention Program (MDPP) Ex...
# 5  Medicare Diabetes Prevention Program (MDPP) Ex...
# 6  Medicare Diabetes Prevention Program (MDPP) Ex...
# 7  Medicare Diabetes Prevention Program (MDPP) Ex...
# 8  Medicare Diabetes Prevention Program (MDPP) Ex...
# 9  Medicare Diabetes Prevention Program (MDPP) Ex...
#
#                                   Organization Name  \
# 0                 Comunidad Saludable De La Montana
# 1                 Comunidad Saludable De La Montana
# 2                 Comunidad Saludable De La Montana
# 3  Hockomock Young Men'S Christian Association Inc.
# 4  Hockomock Young Men'S Christian Association Inc.
# ...

# %% [markdown]
# **_____________________________________________________________________________________**

# %% [markdown]
# ### XLSX File Datasets:

# %% [markdown]
# **XLSX 1: The information provided in this dataset describes the percentage of total lyme disease cases by age group and sex. Columns include year, age group, sex, and percent of total cases.**
#
# https://www.cdc.gov/lyme/datasurveillance/surveillance-data.html?CDC_AA_refVal=https%3A%2F%2Fwww.cdc.gov%2Flyme%2Fdatasurveillance%2Frecent-surveillance-data.html

# %%
excel1 = pd.read_excel('Lyme_Disease_Percent_of_Total_Cases_by_Age_Group_and_Year.xlsx')
excel1
# Out:
#      Year            Age Group     Sex  % of Total Cases
# 0    2008                  0-4  Female            0.0179
# 1    2008                  0-4    Male            0.0211
# 2    2008  2023-05-09 00:00:00  Female            0.0365
# 3    2008  2023-05-09 00:00:00    Male            0.0552
# 4    2008  2023-10-14 00:00:00  Female            0.0277
# ..    ...                  ...     ...               ...
# 499  2021                75-79    Male            0.0237
# 500  2021                80-84  Female            0.0136
# 501  2021                80-84    Male            0.0141
# 502  2021                  85+  Female            0.0068
# 503  2021                  85+    Male            0.0082
#
# [504 rows x 4 columns]

# %%
excel1_top10 = excel1.head(10)
print('First 10 rows: ')
excel1_top10
# Out:
# First 10 rows:
#    Year            Age Group     Sex  % of Total Cases
# 0  2008                  0-4  Female            0.0179
# 1  2008                  0-4    Male            0.0211
# 2  2008  2023-05-09 00:00:00  Female            0.0365
# 3  2008  2023-05-09 00:00:00    Male            0.0552
# 4  2008  2023-10-14 00:00:00  Female            0.0277
# 5  2008  2023-10-14 00:00:00    Male            0.0532
# 6  2008                15-19  Female            0.0231
# 7  2008                15-19    Male            0.0400
# 8  2008                20-24  Female            0.0165
# 9  2008                20-24    Male            0.0232

# %% [markdown]
# **XLSX 2: This dataset provides information on all home health agencies (HHAs) currently enrolled in Medicare. Columns include the enrollment ID of the agencies, the state they are enrolled in, their provider type code, their national provider identifier (NPI), associate ID, organization/business name, organization type, address, and whether they are proprietary or nonprofit. 'Multiple NPI FLag' indicates whether the provider has more than one NPI. 'CCN' indicates CMS certification number.**
#
# https://data.cms.gov/provider-characteristics/hospitals-and-other-facilities/home-health-agency-enrollments

# %%
excel2 = pd.read_excel('HHA_Enrollments_2023.07.06.xlsx')
excel2
# Out:
#          ENROLLMENT ID ENROLLMENT STATE PROVIDER TYPE CODE  \
# 0      O20020806000001               CT              00-06
# 1      O20020807000006               CA              00-06
# 2      O20020809000000               VA              00-06
# 3      O20020809000002               PA              00-06
# 4      O20020811000000               GA              00-06
# ...                ...              ...                ...
# 11497  O20230103001141               FL              00-06
# 11498  O20230103001571               TX              00-06
# 11499  O20230110002902               FL              00-06
# 11500  O20230215000889               OH              00-06
# 11501  O20230511003038               TN              00-06
#
#                          PROVIDER TYPE TEXT         NPI MULTIPLE NPI FLAG  \
# 0      PART A PROVIDER - HOME HEALTH AGENCY  1457434003                 N
# 1      PART A PROVIDER - HOME HEALTH AGENCY  1962462077                 N
# ...

# %%
excel2_top10 = excel2.head(10)
print('First 10 rows: ')
excel2_top10
# Out:
# First 10 rows:
#      ENROLLMENT ID ENROLLMENT STATE PROVIDER TYPE CODE  \
# 0  O20020806000001               CT              00-06
# 1  O20020807000006               CA              00-06
# 2  O20020809000000               VA              00-06
# 3  O20020809000002               PA              00-06
# 4  O20020811000000               GA              00-06
# 5  O20020812000020               CA              00-06
# 6  O20020813000019               VA              00-06
# 7  O20020815000010               MT              00-06
# 8  O20020815000031               AZ              00-06
# 9  O20020827000003               PA              00-06
#
#                      PROVIDER TYPE TEXT         NPI MULTIPLE NPI FLAG     CCN  \
# 0  PART A PROVIDER - HOME HEALTH AGENCY  1457434003                 N   77229
# 1  PART A PROVIDER - HOME HEALTH AGENCY  1962462077                 N   58283
# 2  PART A PROVIDER - HOME HEALTH AGENCY  1881690550                 N  497020
# ...

# %% [markdown]
# **XLSX 3: This dataset includes information about Medicare beneficiaries who used telehealth services January 1, 2020 and December 31, 2022. The year and quarter columns indicates the time frame from when Medicare Part B claims were pulled. Geographic location of beneficiaries are indicated in 'Bene_Geo_Desc'. The next columns indicate medicare/medicaid enrollement status, race, sex, and age. the column 'Bene_RUCA_Desc' indicate rural or urban geographic location. The next columns inicate the number of beneficiaries eligible for telehealth, total Medicare population with Part B Fee-for-Service (FFS) Insurance, the total telehealth users, and percentage of Medicare users with a telehealth service.**
#
# https://data.cms.gov/summary-statistics-on-use-and-payments/medicare-service-type-reports/medicare-telehealth-trends

# %%
excel3 = pd.read_excel('medicare_telehealth_trends.xlsx')
excel3
# Out:
#        Year  quarter  Bene_Geo_Desc Bene_Mdcd_Mdcr_Enrl_Stus Bene_Race_Desc  \
# 0      2020  Overall       National                      All            All
# 1      2020  Overall       National                      All            All
# 2      2020  Overall       National                      All            All
# 3      2020  Overall       National                      All            All
# 4      2020  Overall       National                      All            All
# ...     ...      ...            ...                      ...            ...
# 18055  2022        4       Virginia                      All            All
# 18056  2022        4     Washington                      All            All
# 18057  2022        4  West Virginia                      All            All
# 18058  2022        4      Wisconsin                      All            All
# 18059  2022        4        Wyoming                      All            All
#
# ...

# %%
excel3_top10 = excel3.head(10)
print('First 10 rows: ')
excel3_top10
# Out:
# First 10 rows:
#    Year  quarter Bene_Geo_Desc Bene_Mdcd_Mdcr_Enrl_Stus Bene_Race_Desc  \
# 0  2020  Overall      National                      All            All
# 1  2020  Overall      National                      All            All
# 2  2020  Overall      National                      All            All
# 3  2020  Overall      National                      All            All
# 4  2020  Overall      National                      All            All
# 5  2020  Overall      National                      All            All
# 6  2020  Overall      National                      All            All
# 7  2020  Overall      National                      All            All
# 8  2020  Overall      National                      All            All
# 9  2020  Overall      National                      All            All
#
#   Bene_Sex_Desc Bene_Mdcr_Entlmt_Stus Bene_Age_Desc Bene_RUCA_Desc  \
# 0           All                   All           All            All
# ...

# %% [markdown]
# **_________________________________________________________________________________**

# %% [markdown]
# ### JSON FIle Datasets:

# %% [markdown]
# **JSON 1: This dataset contains information on enrollment of of all hospices currently enrolled in Medicare. Information includes each hospice's unique enrollment ID, the state they are enrolled in, provider type code, national provider identifier (NPI), if they have more than 1 NPI, CMS certification number(CCN), associate ID, organization and business name, and thier incorporation date and state. In addition, information about hospices' organization type, whether they are proprietary or nonprofit, and address is also included.**
# https://data.cms.gov/provider-characteristics/hospitals-and-other-facilities/hospice-enrollments

# %%
json1 = pd.read_json('https://raw.githubusercontent.com/c-susan/datasci_1_loading/main/data/hospice_enrollments.json')
json1
# Out:
#        ENROLLMENT ID ENROLLMENT STATE PROVIDER TYPE CODE  \
# 0    O20020813000008               KS              00-08
# 1    O20020813000010               PA              00-08
# 2    O20020814000022               CA              00-08
# 3    O20020820000009               PA              00-08
# 4    O20020823000006               OR              00-08
# ..               ...              ...                ...
# 995  O20070123000223               SC              00-08
# 996  O20070123000682               CA              00-08
# 997  O20070125000011               OH              00-08
# 998  O20070126000229               LA              00-08
# 999  O20070126000280               LA              00-08
#
#             PROVIDER TYPE TEXT         NPI MULTIPLE NPI FLAG     CCN  \
# 0    PART A PROVIDER - HOSPICE  1144260498                 N  171523
# 1    PART A PROVIDER - HOSPICE  1053393447                 N  391518
# 2    PART A PROVIDER - HOSPICE  1033110994                 N  051693
# ...

# %%
json1_top10 = json1.head(10)
print('First 10 rows" ')
json1_top10
# Out:
# First 10 rows"
#      ENROLLMENT ID ENROLLMENT STATE PROVIDER TYPE CODE  \
# 0  O20020813000008               KS              00-08
# 1  O20020813000010               PA              00-08
# 2  O20020814000022               CA              00-08
# 3  O20020820000009               PA              00-08
# 4  O20020823000006               OR              00-08
# 5  O20020823000007               MO              00-08
# 6  O20020916000026               CA              00-08
# 7  O20020926000017               NE              00-08
# 8  O20021009000011               MO              00-08
# 9  O20021014000008               PA              00-08
#
#           PROVIDER TYPE TEXT         NPI MULTIPLE NPI FLAG      CCN  \
# 0  PART A PROVIDER - HOSPICE  1144260498                 N   171523
# 1  PART A PROVIDER - HOSPICE  1053393447                 N   391518
# 2  PART A PROVIDER - HOSPICE  1033110994                 N   051693
# ...

# %% [markdown]
# **JSON 2: This dataset contains information on contributions from CMS Innovation Center models, demonstrations, initiatives, and programs. The 'Title' column indicates name of the model, demonstration, initiative or program. 'Author' indicates the name(s) of authors. Information on the URL, month and year of publication, abstract, title, keywords, and type of publication is included. The related content columns contain information on resources associated with 'Title' column. The 'ID' column contains a unique number associated with each dataset row. Additional columns include 'At‐A‐Glance Reports URL', 'At‐A‐Glance Reports'.**
#
# https://data.cms.gov/cms-innovation-center-programs/cms-innovation-models-overview/innovation-center-data-and-reports

# %%
json2 = pd.read_json('https://raw.githubusercontent.com/c-susan/datasci_1_loading/main/data/DataReports_InnovationCenter_7_20_23.json')
json2
# Out:
#                                                  Title Author  \
# 0    Evaluation of the Usefulness of Practice Feedb...
# 1    Medication Therapy Management in Chronically I...
# 2    Master System of Records Notice: Center for Me...
# 3    Evaluation of the Medicaid Incentives for the ...
# 4    One Year of Innovation: Taking Action to Impro...
# ..                                                 ...    ...
# 305  Comprehensive Care for Joint Replacement Model...
# 306  Oncology Care Model - Performance Periods 1-9 ...
# 307  White Paper - Assessing Equity to Drive Health...
# 308  End-Stage Renal Disease Treatment Choices (ETC...
# 309  Vermont All-Payer ACO Model (VTAPM) - Third Ev...
#
#                                                    URL Month of Publication  \
# 0    https://innovation.cms.gov/files/reports/pract...             November
# 1    http://innovation.cms.gov/Files/reports/MTM_Fi...               August
# ...

# %%
json2_top10 = json2.head(10)
print('First 10 rows" ')
json2_top10
# Out:
# First 10 rows"
#                                                Title Author  \
# 0  Evaluation of the Usefulness of Practice Feedb...
# 1  Medication Therapy Management in Chronically I...
# 2  Master System of Records Notice: Center for Me...
# 3  Evaluation of the Medicaid Incentives for the ...
# 4  One Year of Innovation: Taking Action to Impro...
# 5  Hospital Acquired Conditions (HAC) - Report to...
# 6  Nursing Home Value-Based Purchasing Demonstrat...
# 7  Using Qualitative Comparative Analysis (QCA) t...
# 8           Report to Congress (December 2012) (PDF)
# 9  Evaluation of the Medicaid Emergency Psychiatr...
#
#                                                  URL Month of Publication  \
# 0  https://innovation.cms.gov/files/reports/pract...             November
# 1  http://innovation.cms.gov/Files/reports/MTM_Fi...               August
# 2          http://innovation.cms.gov/Files/x/SOR.pdf              January
# ...

# %% [markdown]
# **JSON 3: This dataset contain information on listings of events from CMS Innovation Center models, demonstrations, initiatives, and programs. The 'Title' column indicates the type of event, event name, and key theme of discussion. The 'URL' contains the website link for additional information and 'Description' contains a summary of the event or discussion topics. The start and end date and time of each event are also listed. The related item columns contain information associated with the event, 'Upcoming' indicates whether there is a scheduled event, and 'Unique ID' indicates the unique number associated with each row.**
#
# https://data.cms.gov/cms-innovation-center-programs/cms-innovation-models-overview/innovation-center-webinars-and-forums

# %%
json3 = pd.read_json('https://raw.githubusercontent.com/c-susan/datasci_1_loading/main/data/WebinarsForums_InnovationCenter-08-24-23.json')
json3
# Out:
#                                                  Title  \
# 0    Webinar: Comprehensive ESRD Care Model- How to...
# 1    Conference Calls: State Innovation Models Init...
# 2    Open Door Forum #2: Comprehensive ESRD Care Model
# 3       Open Door Forum: Comprehensive ESRD Care Model
# 4    Webinar: Strong Start for Mothers and Newborns...
# ..                                                 ...
# 273  Webinar: Overview of the CY 2024 VBID Model an...
# 274  Office Hours: CY 2024 VBID Model and Applicati...
# 275  Office Hours: BPCI Advanced Model - Year 7 App...
# 276  Office Hours: BPCI Advanced Model - Year 7 App...
# 277                    Webinar: GUIDE Model - Overview
#
#                                                    URL  \
# 0    http://innovation.cms.gov/resources/Comprehens...
# 1    http://innovation.cms.gov/resources/Conference...
# 2    http://innovation.cms.gov/resources/Comprehens...
# 3    http://innovation.cms.gov/resources/Comprehens...
# ...

# %%
json3_top10 = json3.head(10)
print('First 10 rows" ')
json3_top10
# Out:
# First 10 rows"
#                                                Title  \
# 0  Webinar: Comprehensive ESRD Care Model- How to...
# 1  Conference Calls: State Innovation Models Init...
# 2  Open Door Forum #2: Comprehensive ESRD Care Model
# 3     Open Door Forum: Comprehensive ESRD Care Model
# 4  Webinar: Strong Start for Mothers and Newborns...
# 5     Conference Call: Health Care Innovation Awards
# 6  Webinar: Bundled Payments for Care Improvement...
# 7  Webinar: Frontier Community Health Integration...
# 8  Open Door Forum: Seeking Input on ACO Educatio...
# 9  Webinar: State Innovation Models Initiative fo...
#
#                                                  URL  \
# 0  http://innovation.cms.gov/resources/Comprehens...
# 1  http://innovation.cms.gov/resources/Conference...
# 2  http://innovation.cms.gov/resources/Comprehens...
# 3  http://innovation.cms.gov/resources/Comprehens...
# 4  http://innovation.cms.gov/resources/StrongStar...
# ...
